# %% [markdown]
# # Cluster a Likert survey (respondents and questions)
#
# A short, self-contained example. We build a small product-satisfaction survey,
# cluster respondents and questions with `cluster_survey`, pull out the question
# clusters, and draw the heatmap. No `[nlp]` extra / torch required.

# %%
import numpy as np
import pandas as pd

import pandas_survey_toolkit.nlp  # noqa: F401  (registers the .cluster_* methods)
from pandas_survey_toolkit.vis import cluster_heatmap_plot, survey_clustermap

# %% [markdown]
# ## Sample data
#
# Two themes (service, value) with independent opinions, so the questions form two
# groups and respondents form opinion camps.

# %%
np.random.seed(0)
POS = ["Neutral", "Agree", "Agree", "Strongly Agree"]
NEG = ["Neutral", "Disagree", "Disagree", "Strongly Disagree"]
service = ["q1_ease_of_use", "q2_customer_service", "q3_reliability"]
value = ["q4_value_for_money", "q5_vs_competitors", "q6_would_recommend"]
questions = service + value

rows = []
for _ in range(80):
    s = np.random.rand() < 0.5
    v = np.random.rand() < 0.5
    row = {q: np.random.choice(POS if s else NEG) for q in service}
    row.update({q: np.random.choice(POS if v else NEG) for q in value})
    rows.append(row)
df = pd.DataFrame(rows)
df["respondent_id"] = range(len(df))
df.head()

# %% [markdown]
# ## Cluster both axes at once

# %%
survey = df.cluster_survey(columns=questions)
survey["respondent_cluster_id"].value_counts()

# %% [markdown]
# ## Question clusters (a Series you can save to CSV)

# %%
df.cluster_questions(columns=questions)

# %% [markdown]
# ## Heatmap (questions auto-ordered by cluster)

# %%
encoded = [f"likert_encoded_{q}" for q in questions]
cluster_heatmap_plot(
    survey, respondent_col="respondent_cluster_id", question_cols=encoded, max_width=30
)

# %% [markdown]
# ## Clustermap (per-respondent view with dendrograms)

# %%
survey_clustermap(df, columns=questions, label_col="respondent_id")
